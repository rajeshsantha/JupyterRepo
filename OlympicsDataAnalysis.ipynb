# %%
import org.apache.spark.sql._
# Out:
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# ***** missing reference, looking for Serializable/T in package scala
# decls = Scope{
#   abstract trait Function19?
#   final lazy module object Function19?
#   final module object Function19: <notype>
#   final class UninitializedError?
#   final lazy module object UninitializedError?
#   final module object UninitializedError?
# ...

# %%
val spark = {
  NotebookSparkSession.builder()
    .master("local[*]")
    .getOrCreate()
}
# Out:
# -- [E006] Not Found Error: cmd3.sc:2:2 -----------------------------------------
# 2 |  NotebookSparkSession.builder()
#   |  ^^^^^^^^^^^^^^^^^^^^
#   |  Not found: NotebookSparkSession
#   |
#   | longer explanation available when compiling with `-explain`
# Compilation Failed
# : Compilation Failed
